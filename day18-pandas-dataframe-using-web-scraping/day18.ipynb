# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %% [markdown]
# # if response code is 403
#  - headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
#  -requests.get('url',headers=headers).text

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) AppleWebKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
url = 'https://remoteok.com/remote-engineer-jobs'
webpage = requests.get(url ,headers=headers).text

# %%
# webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
# print(soup.prettify())

# %%
soup.find('table')
#soup.find_all('table')[0].text
# Out:
# <table id="jobsboard">
# <thead>
# <tr>
# <th class="filter-actions" colspan="10" style="padding:0;">
# <div class="top-bar-avatar">
# <img class="top-bar-avatar-img" src="/cdn-cgi/image/format=auto,fit=contain,width=100,height=100,quality=85/https://remoteok.com/assets/logo-square.png?1633381266"/>
# </div>
# <span class="dropdown-toggle"></span>
# <div class="search-filter">
# <input autocomplete="google_chrome_fix" class="search-filter-input" placeholder="🔍 Search" type="text"/>
# <div class="search-filter-input-icon-circle">
# <div class="search-filter-input-icon"></div>
# </div>
# </div>
# <div class="location-filter">
# <input autocomplete="google_chrome_fix" class="location-filter-input" placeholder="🌏 Location" type="text"/>
# <div class="location-filter-icon-circle">
# <div class="location-filter-icon"></div>
# </div>
# </div>
# <div class="salary-filter">
# <div>
# 												💵 Salary
# 											</div>
# <div class="salary-filter-icon-circle">
# ...

# %%
a = soup.find_all('a', class_="preventLink")
role = []
for i in a:
    h2 = i.find('h2')
    if h2:
        role.append(h2.text.strip())
print('\n'.join(role))
# Out:
# Senior Golang Engineer
# Senior Data Analytics Engineer
# Javascript Fullstack Engineer Senior
# Sr Software Engineer Cross Platform Applications
# Sr Software Engineer Backend Web Applications
# Smart Contract Engineer
# Design Centric Senior Front End Engineer
# Senior Software Engineer Hosted Team
# Sr Software Engineer
# Senior Front End Engineer
# Technical Documentation Engineer
# Software Engineer III
# Data and Business Intelligence Engineer Mid Level Fully
# Senior Software Engineer
# Member of Technical Staff Transparency Front End Engineer
# Backend Software Engineer
# QA Engineer
# Software Engineer Android
# Fullstack Software Engineer
# Lead Backend Engineer Debugger

# %% [markdown]
# # TO FIND OUT NAMES OF THE COMPANIES

# %%
spans = soup.find_all('span', class_="companyLink")
company = []
for span in spans:
    h3 = span.find('h3')
    if h3:
        company.append(h3.text.strip())

print('\n'.join(company))
# Out:
# WunderGraph
# Fullscript
# Lumenalta
# Smallstep
# Smallstep
# Risk Labs
# Dapper Labs
# Cast AI
# Smallstep
# Maxflow BV / CrazyGames
# Tether Operations Limited
# Nextech
# Utility Profit + Sunroom
# Nava
# Anchorage Digital
# Firework
# Contra
# Ontic
# BlackCloak
# Tenderly

# %%
location = []
salary = []

divs = soup.find_all('div', class_="tooltip-set")
for div in divs:
    if div.text[0] == '💰':
        salary.append(div.text.strip())

d = {'salary':salary}
d
#pd.DataFrame(d)
# Out:
# {'salary': []}

# %%
#for in soup.find_all('p'):
  #print(i.text.strip())

# %% [markdown]
# ## TO FIND OUT THE RATINGS

# %%
len(soup.find_all('p',class_='rating'))
# Out:
# 30

# %% [markdown]
# ## TO FIND OUT THE NUMBER OF REVIEWS

# %%
len(soup.find_all('a' , class_='review-count'))
# Out:
# 30

# %% [markdown]
# # CONSIDERING THE WHOLE CONTAINER

# %%
company=soup.find_all('div',class_='company-content-wrapper')

# %%
len(company)
# Out:
# 30

# %%
name=[]
rating=[]
reviews=[]
ctype=[]
hq=[]
how_old=[]
no_of_employee=[]

for i in company:

  name.append(i.find('h2').text.strip())
  rating.append(i.find('p',class_='rating').text.strip())
  reviews.append(i.find('a' , class_='review-count').text.strip())
  ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
  hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
  how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
  no_of_employee.append(i.find_all('p',class_='infoEntity')[3].text.strip())

df=pd.DataFrame({'name':name,
   'rating':rating,
   'reviews':reviews,
   'company_type':ctype,
   'Head_Quarters':hq,
   'Company_Age':how_old,
   'No_of_Employee':no_of_employee,
   })

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'ICICI Bank',
#  'Cognizant',
#  'HDFC Bank',
#  'Capgemini',
#  'Tech Mahindra',
#  'HCL Technologies',
#  'L&T',
#  'Infosys',
#  'Tata Motors',
#  'IBM',
#  'Genpact',
#  'Reliance jio',
#  'Axis Bank',
#  'Wipro',
#  'Concentrix Corporation',
#  'HDB Financial Services',
#  'Vodafone',
#  'Bharti Airtel',
#  'Kotak Mahindra Bank',
#  'Amazon',
#  'Reliance',
#  'Bajaj Finserv',
#  'IndusInd Bank',
#  'Indian Army',
#  'Teleperformance',
#  'Hinduja Global Solutions',
#  'Samsung',
#  'Mahindra & Mahindra']

# %%
rating
# Out:
# ['3.9',
#  '4.0',
#  '4.1',
#  '3.9',
#  '4.0',
#  '3.4',
#  '3.6',
#  '3.7',
#  '4.2',
#  '3.9',
#  '4.1',
#  '4.1',
#  '4.0',
#  '4.0',
#  '4.0',
#  '3.8',
#  '4.0',
#  '4.0',
#  '4.2',
#  '4.2',
#  '3.8',
#  '4.1',
#  '4.2',
#  '4.1',
#  '3.6',
#  '4.7',
#  '3.7',
#  '3.8',
#  '4.2',
#  '4.2']

# %%
reviews
# Out:
# ['17.1k Reviews',
#  '15k Reviews',
#  '13.8k Reviews',
#  '12.9k Reviews',
#  '12k Reviews',
#  '10k Reviews',
#  '9.8k Reviews',
#  '9.2k Reviews',
#  '9.1k Reviews',
#  '8.7k Reviews',
#  '8.6k Reviews',
#  '8.5k Reviews',
#  '8.3k Reviews',
#  '8.3k Reviews',
#  '8.3k Reviews',
#  '7.3k Reviews',
#  '7.3k Reviews',
#  '6.2k Reviews',
#  '5.7k Reviews',
#  '5.7k Reviews',
#  '5.7k Reviews',
#  '5.6k Reviews',
#  '4.8k Reviews',
#  '4.1k Reviews',
#  '3.9k Reviews',
#  '3.9k Reviews',
#  '3.8k Reviews',
#  '3.8k Reviews',
#  '3.6k Reviews',
#  '3.6k Reviews']

# %%
ctype
# Out:
# ['Public',
#  'Private',
#  'Public',
#  'Private',
#  'Public',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Govt agency',
#  'Private',
#  'Public',
#  'Private',
#  'Public']

# %%
hq
# Out:
# ['Mumbai + 164 more',
#  'Dublin + 98 more',
#  'Mumbai + 743 more',
#  'Teaneck + 46 more',
#  'Mumbai + 729 more',
#  'Paris + 45 more',
#  'Pune + 160 more',
#  'Noida + 111 more',
#  'Mumbai + 337 more',
#  'Bangalore + 68 more',
#  'Pune + 344 more',
#  'New York + 73 more',
#  'New York + 31 more',
#  'Navi Mumbai + 606 more',
#  'Mumbai + 670 more',
#  'Bangalore + 123 more',
#  'Fremont + 39 more',
#  'Ahmedabad + 463 more',
#  'Berkshire + 364 more',
#  'New Delhi + 347 more',
#  'Mumbai + 361 more',
#  'Washington + 182 more',
#  'Mumbai + 216 more',
#  'Pune + 478 more',
#  'Mumbai + 365 more',
#  'New Delhi + 211 more',
#  'Paris + 45 more',
#  'Bangalore + 52 more',
#  'Seoul + 292 more',
#  'Mumbai + 268 more']

# %%
how_old
# Out:
# ['52 years old',
#  '31 years old',
#  '26 years old',
#  '26 years old',
#  '26 years old',
#  '53 years old',
#  '34 years old',
#  '14 years old',
#  '82 years old',
#  '39 years old',
#  '75 years old',
#  '109 years old',
#  '23 years old',
#  '10 years old',
#  '27 years old',
#  '75 years old',
#  '37 years old',
#  '13 years old',
#  '38 years old',
#  '25 years old',
#  '17 years old',
#  '26 years old',
#  '54 years old',
#  '13 years old',
#  '26 years old',
#  '125 years old',
#  '42 years old',
#  '20 years old',
#  '82 years old',
#  '75 years old']

# %%
no_of_employee
# Out:
# ['10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees',
#  '10000+ employees']

# %%
df.shape
# Out:
# (30, 7)

# %% [markdown]
# # creating dataframe for all the pages

# %%
dfs = []  # ← list to collect each page’s DataFrame

for j in range(1, 504):
    webpage = requests.get(
        f'https://www.ambitionbox.com/list-of-companies?page={j}'
    ).text
    soup = BeautifulSoup(webpage, 'lxml')
    company = soup.find_all('div', class_='company-content-wrapper')

    # temporary lists for this page
    name = []
    rating = []
    reviews = []
    ctype = []
    hq = []
    how_old = []
    no_of_employee = []

    for i in company:
        # each of these try/except blocks stays the same
        try:
            name.append(i.find('h2').text.strip())
        except:
            name.append(np.nan)

        try:
            rating.append(i.find('p', class_='rating').text.strip())
        except:
            rating.append(np.nan)

        try:
            reviews.append(i.find('a', class_='review-count').text.strip())
        except:
            reviews.append(np.nan)

        try:
            ctype.append(i.find_all('p', class_='infoEntity')[0].text.strip())
        except:
            ctype.append(np.nan)

        try:
            hq.append(i.find_all('p', class_='infoEntity')[1].text.strip())
        except:
            hq.append(np.nan)

        try:
            how_old.append(i.find_all('p', class_='infoEntity')[2].text.strip())
        except:
            how_old.append(np.nan)

        try:
            no_of_employee.append(i.find_all('p', class_='infoEntity')[3].text.strip())
        except:
            no_of_employee.append(np.nan)

    # build the DataFrame for this page
    df = pd.DataFrame({
        'name': name,
        'rating': rating,
        'reviews': reviews,
        'company_type': ctype,
        'Head_Quarters': hq,
        'Company_Age': how_old,
        'No_of_Employee': no_of_employee,
    })

    dfs.append(df)  # ← append the page-DF to our list

# once the loop is done, merge them all in one go
final = pd.concat(dfs, ignore_index=True)

# %%
df.sample(5)
# Out:
#                            name rating  ...    Company_Age    No_of_Employee
# 2               Bank of America    4.3  ...   22 years old  10000+ employees
# 22               R.R. Donnelley    4.1  ...  156 years old  10000+ employees
# 11  Mahindra Holidays & Reso...    3.9  ...   24 years old  10000+ employees
# 23  GVK Emergency Management...    3.9  ...   15 years old  10000+ employees
# 9            Itc Infotech India    3.4  ...   20 years old  10000+ employees
#
# [5 rows x 7 columns]

# %%
df.shape
# Out:
# (30, 7)

# %%
final.shape
# Out:
# (30000, 7)
